# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
population = [
1450935.79,1408975.00,340110.99,283487.93,
251269.16,232679.48,211998.57,173562.36,
143533.85,130861.01
]

plt.figure(figsize=(8,5))
plt.hist(population, bins=5)

plt.title("Distribution of Country Populations")
plt.xlabel("Population (Thousands)")
plt.ylabel("Number of Countries")

plt.show()
